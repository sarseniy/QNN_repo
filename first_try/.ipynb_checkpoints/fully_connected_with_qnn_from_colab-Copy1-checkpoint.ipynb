# %% [markdown]
# # Satifsying requirements

# %%
# !pip install pennylane --upgrade

# %%
# !pip install torch

# %%
import torch
import pennylane as qml
import numpy as np

# %matplotlib inline

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))
# Out:
# Using cuda device

# %% [markdown]
# # Downloading data

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %% [markdown]
# # Preparing data with DataLoaders

# %%
from torch.utils.data import DataLoader

loaders = {
    'train' : torch.utils.data.DataLoader(train_data, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1,
                                          pin_memory=True),
    
    'test'  : torch.utils.data.DataLoader(test_data, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1,
                                          pin_memory=True),
}

# %% [markdown]
# # Defining a NN

# %%
n_qubits = 5
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, interface="torch")
def qnode(inputs, weights):
    qml.templates.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.templates.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
n_layers = 5
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
import torch.nn as nn

class HybridNN(nn.Module):
    def __init__(self):
        super(HybridNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(
                in_channels=16,              
                out_channels=32,            
                kernel_size=5,              
                stride=1,                   
                padding=2,    
            ),     
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),                
        )
        self.fc_1 = nn.Linear(32 * 7 * 7, 20)
        
        # LIST USAGE?
        self.qlayer_1 = qml.qnn.TorchLayer(qnode, weight_shapes)
        self.qlayer_2 = qml.qnn.TorchLayer(qnode, weight_shapes)
        self.qlayer_3 = qml.qnn.TorchLayer(qnode, weight_shapes)
        self.qlayer_4 = qml.qnn.TorchLayer(qnode, weight_shapes)
        
        self.qlayer_1.to(device)
        self.qlayer_2.to(device)
        self.qlayer_3.to(device)
        self.qlayer_4.to(device)
        
        self.fc_2 = nn.Linear(20, 10)

        
    def forward(self, x):

        x = self.conv1(x)

        x = self.conv2(x)

        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1) 

        x = self.fc_1(x)
        #print('Before split')
        x_1, x_2, x_3, x_4 = torch.split(x, 5, dim=1) # second argument is number of elements in one new tensor
        #print('After split')
        #x = torch.Tensor(0)
        
        x_1 = self.qlayer_1(x_1)
        x_2 = self.qlayer_2(x_2)
        x_3 = self.qlayer_3(x_3)
        x_4 = self.qlayer_4(x_4)
        
        #print(x.device)
        
        x = torch.cat([x_1, x_2, x_3, x_4], axis=1)
        x = x.to(device)
        
        logits = self.fc_2(x)
        
        return logits

# %%
hnn = HybridNN()
hnn = hnn.to(device)
print(hnn)
# Out:
# HybridNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_1): Linear(in_features=1568, out_features=20, bias=True)
#   (qlayer_1): <Quantum Torch Layer: func=qnode>
#   (qlayer_2): <Quantum Torch Layer: func=qnode>
#   (qlayer_3): <Quantum Torch Layer: func=qnode>
#   (qlayer_4): <Quantum Torch Layer: func=qnode>
#   (fc_2): Linear(in_features=20, out_features=10, bias=True)
# )

# %% [markdown]
# # Training

# %%
loss_func = nn.CrossEntropyLoss()

# %%
from torch import optim

optimizer = optim.Adam(hnn.parameters(), lr = 0.01)

# %%
from tqdm.notebook import trange
from torch.autograd import Variable

def train(num_epochs, model, loaders):
    
    model.train()
        
    # Train the model
    total_step = len(loaders['train'])
        
    for epoch in trange(num_epochs):
        for i, (images, labels) in enumerate(loaders['train']):
            
            b_x, b_y = images.to(device), labels.to(device)

            output = model(b_x)             
            loss = loss_func(output, b_y)
            
            optimizer.zero_grad()           
            
            loss.backward()               
            optimizer.step()                
            
            if (i+1) % 10 == 0:
                print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
        print('\n')

# %%
num_epochs = 10

train(num_epochs, hnn, loaders)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch [1/10], Step [10/600], Loss: 2.3211
# Epoch [1/10], Step [20/600], Loss: 2.3235
# Epoch [1/10], Step [30/600], Loss: 2.3285
# Epoch [1/10], Step [40/600], Loss: 2.3325
# Epoch [1/10], Step [50/600], Loss: 2.2960
# Epoch [1/10], Step [60/600], Loss: 2.2178
# Epoch [1/10], Step [70/600], Loss: 1.9805
# Epoch [1/10], Step [80/600], Loss: 1.7017
# Epoch [1/10], Step [90/600], Loss: 1.4714
# Epoch [1/10], Step [100/600], Loss: 1.2057
# Epoch [1/10], Step [110/600], Loss: 0.9985
# Epoch [1/10], Step [120/600], Loss: 0.7097
# Epoch [5/10], Step [10/600], Loss: 0.0513
# Epoch [5/10], Step [20/600], Loss: 0.1163
# Epoch [5/10], Step [30/600], Loss: 0.0601
# Epoch [5/10], Step [40/600], Loss: 0.0962
# Epoch [5/10], Step [50/600], Loss: 0.0852
# Epoch [5/10], Step [60/600], Loss: 0.0189
# Epoch [5/10], Step [70/600], Loss: 0.0525
# Epoch [5/10], Step [80/600], Loss: 0.0925
# Epoch [5/10], Step [90/600], Loss: 0.0947
# Epoch [5/10], Step [100/600], Loss: 0.1899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-dac347325ae2> in <module>
#       1 num_epochs = 10
#       2
# ----> 3 train(num_epochs, hnn, loaders)
#
# <ipython-input-17-d62a7ad40f92> in train(num_epochs, model, loaders)
#      14             b_x, b_y = images.to(device), labels.to(device)
#      15
# ---> 16             output = model(b_x)
#      17             loss = loss_func(output, b_y)
#      18
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-9-714779247a5b> in forward(self, x)
#      58
#      59         x_1 = self.qlayer_1(x_1)
# ---> 60         x_2 = self.qlayer_2(x_2)
#      61         x_3 = self.qlayer_3(x_3)
#      62         x_4 = self.qlayer_4(x_4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\qnn\torch.py in forward(self, inputs)
#     272             reconstructor = []
#     273             for x in torch.unbind(inputs):
# --> 274                 reconstructor.append(self.forward(x))
#     275             return torch.stack(reconstructor)
#     276
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\qnn\torch.py in forward(self, inputs)
#     276
#     277         # If the input is 1-dimensional, calculate the forward pass as usual
# --> 278         return self._evaluate_qnode(inputs)
#     279
#     280     def _evaluate_qnode(self, x):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\qnn\torch.py in _evaluate_qnode(self, x)
#     291             **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     292         }
# --> 293         return self.qnode(**kwargs).type(x.dtype)
#     294
#     295     def __str__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\qnode.py in __call__(self, *args, **kwargs)
#     685             res = fn(results)
#     686         else:
# --> 687             res = self.qtape.execute(device=self.device)
#     688
#     689         finite_diff = any(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\tape\tape.py in execute(self, device, params)
#    1320             params = self.get_parameters()
#    1321
# -> 1322         return self._execute(params, device=device)
#    1323
#    1324     def execute_device(self, params, device):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\tape\tape.py in execute_device(self, params, device)
#    1351
#    1352         if isinstance(device, qml.QubitDevice):
# -> 1353             res = device.execute(self)
#    1354         else:
#    1355             res = device.execute(self.operations, self.observables, {})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\_qubit_device.py in execute(self, circuit, **kwargs)
#     192
#     193         # apply all circuit operations
# --> 194         self.apply(circuit.operations, rotations=circuit.diagonalizing_gates, **kwargs)
#     195
#     196         # generate computational basis samples
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in apply(self, operations, rotations, **kwargs)
#     213                 self._apply_basis_state(operation.parameters[0], operation.wires)
#     214             else:
# --> 215                 self._state = self._apply_operation(self._state, operation)
#     216
#     217         # store the pre-rotated state
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit_torch.py in _apply_operation(self, state, operation)
#     299         if state.device != self._torch_device:
#     300             state = state.to(self._torch_device)
# --> 301         return super()._apply_operation(state, operation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in _apply_operation(self, state, operation)
#     236         if operation.base_name in self._apply_ops:
#     237             axes = self.wires.indices(wires)
# --> 238             return self._apply_ops[operation.base_name](state, axes, inverse=operation.inverse)
#     239
#     240         matrix = self._get_unitary_matrix(operation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in _apply_cnot(self, state, axes, **kwargs)
#     355             target_axes = [axes[1]]
#     356
# --> 357         state_x = self._apply_x(state[sl_1], axes=target_axes)
#     358         return self._stack([state[sl_0], state_x], axis=axes[0])
#     359
#
# C:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in _apply_x(self, state, axes, **kwargs)
#     263             array[complex]: output state
#     264         """
# --> 265         return self._roll(state, 1, axes[0])
#     266
#     267     def _apply_y(self, state, axes, **kwargs):
#
# KeyboardInterrupt:

# %%
torch.save(hnn.state_dict(), 'trained_model_10qubits.pt')
